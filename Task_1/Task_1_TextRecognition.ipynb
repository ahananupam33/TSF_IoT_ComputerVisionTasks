# %% [markdown]
# # The Sparks Foundation
# # IoT  and Computer Vision Internship
# # #Task 1 : Optical Character Recognition (OCR)
# ## To detect text from a given image
# ## Done by : Ahan Anupam

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import cv2
import pytesseract
import matplotlib.pyplot as plt

# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Getting the image

# %%
image = cv2.imread('TextImage_3.png')

# %%
plt.imshow(image)

# %% [markdown]
# ### Converting to a grayscale image

# %%
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# ### Peforming Erosion and Dilation to detect text

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.dilate(image, kernel, iterations=1)
img = cv2.erode(gray, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print(out_below)
# Out:
#
#
# ‘Tomorrow, and
# tomorrow, and
# tomorrow; creeps
# n this pelly pace
# from day to day,
# until the last syll-
# able of recorded
# time. And all our
# yesterdays have
# lighted fools the
# way lo dusly
